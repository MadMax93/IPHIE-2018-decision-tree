# %%
import pandas as pd

# %%
data = pd.read_csv("diabetic_data.csv")

# %%
data.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# 0                 1    ...              No      No                   No
# 1                 3    ...              No      Up                   No
# 2                 2    ...              No      No                   No
# 3                 2    ...              No      Up                   No
# 4                 1    ...              No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
##drop the weight and payer_code column due to high rates of missing data
data = data.drop(['weight', 'payer_code'], axis=1)

# %%
len(data)
# Out:
# 101766

# %%
##Omit discharge disposition ids that correspond to hospice or death. These include: 11, 13, 14, 19, 20, 21.
a = [11, 13, 14, 19, 20, 21]
data = data[~data.discharge_disposition_id.isin(a)]

# %%
len(data)
# Out:
# 99343

# %%
##make function to recode readmission, 0 is no readmission or >30 days, <30 days is an early readmission
def recode(x):
    if x == 'NO'or x == '>30':
        return 0
    else:
        return 1

# %%
##recode readmission
data['readmitted'] = data['readmitted'].apply(recode)

# %%
data.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392      8222157        Caucasian  Female   [0-10)
# 1        149190     55629189        Caucasian  Female  [10-20)
# 2         64410     86047875  AfricanAmerican  Female  [20-30)
# 3        500364     82442376        Caucasian    Male  [30-40)
# 4         16680     42519267        Caucasian    Male  [40-50)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital         medical_specialty     ...      citoglipton  \
# 0                 1  Pediatrics-Endocrinology     ...               No
# 1                 3                         ?     ...               No
# 2                 2                         ?     ...               No
# 3                 2                         ?     ...               No
# 4                 1                         ?     ...               No
#
#    insulin  glyburide-metformin  glipizide-metformin  \
# 0       No                   No                   No
# 1       Up                   No                   No
# 2       No                   No                   No
# 3       Up                   No                   No
# 4   Steady                   No                   No
#
#    glimepiride-pioglitazone  metformin-rosiglitazone metformin-pioglitazone  \
# 0                        No                       No                     No
# 1                        No                       No                     No
# 2                        No                       No                     No
# 3                        No                       No                     No
# 4                        No                       No                     No
#
#   change diabetesMed  readmitted
# 0     No          No           0
# 1     Ch         Yes           0
# 2     No         Yes           0
# 3     Ch         Yes           0
# 4     Ch         Yes           0
#
# [5 rows x 48 columns]

# %%
data2 = data.loc[data.groupby("patient_nbr")["encounter_id"].idxmin()]

# %%
len(data2)
# Out:
# 69990

# %%
data2 = data2.reset_index()

# %%
data2["patient_nbr"] = data2["index"]

# %%
data2.head()
# Out:
#    index  encounter_id  patient_nbr             race  gender      age  \
# 0   4267      24437208         4267        Caucasian  Female  [50-60)
# 1   5827      29758806         5827        Caucasian  Female  [50-60)
# 2  67608     189899286        67608        Caucasian  Female  [80-90)
# 3  17494      64331490        17494        Caucasian  Female  [80-90)
# 4   2270      14824206         2270  AfricanAmerican  Female  [30-40)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  2                         1                    1
# 1                  3                         1                    1
# 2                  1                         3                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital    ...     citoglipton  insulin  glyburide-metformin  \
# 0                 8    ...              No   Steady                   No
# 1                 2    ...              No       No                   No
# 2                 4    ...              No       No                   No
# 3                 3    ...              No       No                   No
# 4                 5    ...              No       No                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone change diabetesMed readmitted
# 0                      No     Ch         Yes          1
# 1                      No     No          No          0
# 2                      No     No         Yes          0
# 3                      No     Ch         Yes          0
# 4                      No     No         Yes          0
#
# [5 rows x 49 columns]

# %%
data2 = data2.drop(["index"], axis=1)
data2.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0      24437208         4267        Caucasian  Female  [50-60)
# 1      29758806         5827        Caucasian  Female  [50-60)
# 2     189899286        67608        Caucasian  Female  [80-90)
# 3      64331490        17494        Caucasian  Female  [80-90)
# 4      14824206         2270  AfricanAmerican  Female  [30-40)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  2                         1                    1
# 1                  3                         1                    1
# 2                  1                         3                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital medical_specialty     ...      citoglipton  insulin  \
# 0                 8        Cardiology     ...               No   Steady
# 1                 2     Surgery-Neuro     ...               No       No
# 2                 4  InternalMedicine     ...               No       No
# 3                 3  InternalMedicine     ...               No       No
# 4                 5  InternalMedicine     ...               No       No
#
#    glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 0                   No                   No                        No
# 1                   No                   No                        No
# 2                   No                   No                        No
# 3                   No                   No                        No
# 4                   No                   No                        No
#
#    metformin-rosiglitazone metformin-pioglitazone change diabetesMed  \
# 0                       No                     No     Ch         Yes
# 1                       No                     No     No          No
# 2                       No                     No     No         Yes
# 3                       No                     No     Ch         Yes
# 4                       No                     No     No         Yes
#
#    readmitted
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
#
# [5 rows x 48 columns]

# %%
data2.to_csv("19062018_dataset_cleaned.csv", sep=",")

# %%
unique_patients = list(set(data.patient_nbr.values))

# %%
import numpy as np

# %%
test = list()
for pat in unique_patients:
    rows = data.loc[data["patient_nbr"] == pat]
    if len(rows) > 1:
        lowest = np.min(rows["encounter_id"].values)
        selection = rows.loc[rows["encounter_id"] == lowest]
        test.append(selection)
        continue;
    test.append(rows)

# %%
len(test)

# %%
test[0]

# %%
df_result = pd.DataFrame(test,columns=data.columns)

# %%
df_result.head()
# Out:
#        encounter_id  patient_nbr       race  gender      age  \
# 47144     145090254     33947649  Caucasian  Female  [70-80)
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 47144                  5                         6                    1
#
#        time_in_hospital medical_specialty     ...      citoglipton  insulin  \
# 47144                 9                 ?     ...               No   Steady
#
#        glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 47144                   No                   No                        No
#
#        metformin-rosiglitazone metformin-pioglitazone change diabetesMed  \
# 47144                       No                     No     No         Yes
#
#        readmitted
# 47144           0
#
# [1 rows x 48 columns]

# %%
data2.head()
# Out:
#        encounter_id  patient_nbr       race  gender      age  \
# 4780       26264286          135  Caucasian  Female  [50-60)
# 4267       24437208          135  Caucasian  Female  [50-60)
# 5827       29758806          378  Caucasian  Female  [50-60)
# 67608     189899286          729  Caucasian  Female  [80-90)
# 17494      64331490          774  Caucasian  Female  [80-90)
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 4780                   1                         1                    7
# 4267                   2                         1                    1
# 5827                   3                         1                    1
# 67608                  1                         3                    7
# 17494                  1                         1                    7
#
#        time_in_hospital                medical_specialty     ...      \
# 4780                  3  Surgery-Cardiovascular/Thoracic     ...
# 4267                  8                       Cardiology     ...
# 5827                  2                    Surgery-Neuro     ...
# 67608                 4                 InternalMedicine     ...
# 17494                 3                 InternalMedicine     ...
#
#        citoglipton  insulin  glyburide-metformin  glipizide-metformin  \
# 4780            No       No                   No                   No
# 4267            No   Steady                   No                   No
# 5827            No       No                   No                   No
# 67608           No       No                   No                   No
# 17494           No       No                   No                   No
#
#        glimepiride-pioglitazone  metformin-rosiglitazone  \
# 4780                         No                       No
# 4267                         No                       No
# 5827                         No                       No
# 67608                        No                       No
# 17494                        No                       No
#
#       metformin-pioglitazone change diabetesMed  readmitted
# 4780                      No     Ch         Yes           0
# 4267                      No     Ch         Yes           1
# 5827                      No     No          No           0
# 67608                     No     No         Yes           0
# 17494                     No     Ch         Yes           0
#
# [5 rows x 48 columns]

# %%
df_counts = pd.DataFrame(data['patient_nbr'].value_counts()).reset_index()

# %%
df_counts.head()
# Out:
#       index  patient_nbr
# 0  88785891           40
# 1  43140906           28
# 2   1660293           23
# 3  88227540           23
# 4  23199021           23

# %%
df_counts = df_counts.loc[df_counts["patient_nbr"] > 1]
data2 = data.loc[data["patient_nbr"].isin(df_counts["index"])]

# %%
data2.head()
# Out:
#     encounter_id  patient_nbr       race  gender      age  admission_type_id  \
# 12         40926     85504905  Caucasian  Female  [40-50)                  1
# 27        248916    115196778  Caucasian  Female  [50-60)                  1
# 28        250872     41606064  Caucasian    Male  [20-30)                  2
# 32        260166     80845353  Caucasian  Female  [70-80)                  1
# 33        293058    114715242  Caucasian    Male  [60-70)                  2
#
#     discharge_disposition_id  admission_source_id  time_in_hospital  \
# 12                         3                    7                 7
# 27                         1                    1                 2
# 28                         1                    2                10
# 32                         1                    7                 6
# 33                         6                    2                 5
#
#          medical_specialty     ...      citoglipton  insulin  \
# 12  Family/GeneralPractice     ...               No     Down
# 27         Surgery-General     ...               No   Steady
# 28                       ?     ...               No     Down
# 32  Family/GeneralPractice     ...               No   Steady
# 33                       ?     ...               No   Steady
#
#     glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 12                   No                   No                        No
# 27                   No                   No                        No
# 28                   No                   No                        No
# 32                   No                   No                        No
# 33                   No                   No                        No
#
#     metformin-rosiglitazone metformin-pioglitazone change diabetesMed  \
# 12                       No                     No     Ch         Yes
# 27                       No                     No     No         Yes
# 28                       No                     No     Ch         Yes
# 32                       No                     No     No         Yes
# 33                       No                     No     No         Yes
#
#     readmitted
# 12           1
# 27           0
# 28           0
# 32           0
# 33           0
#
# [5 rows x 48 columns]

# %%
data["multiple_visits"] = data.loc[data["patient_nbr"].isin(data2["patient_nbr"])]

# %%
##
data1 = open('temp1_new.csv', 'r')
line1 = data1.readline()
pt_encounter = dict()
for line in data1:
    items = line.strip('\n').split(',')
    encounter_id = items[0]
    pt_id = items[1]
    if pt_id not in pt_encounter:
        pt_encounter[pt_id] = encounter_id
    elif int(items[0]) < int(pt_encounter[pt_id]):
        pt_encounter[pt_id] = items[0]
print ('finish part1')
data1.close() 
print (len(pt_encounter))

# %%
pt_encounter
# Out:
# {}
